# %%
import IPython.nbformat.current as convert
conv = convert.read(open('/content/drive/MyDrive/Ragu/Copy of Untitled1.ipynb', 'r'), 'py')
convert.write(conv, open('/content/drive/MyDrive/Ragu/Copy of Untitled1.ipynb', 'w'), 'ipynb')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/nbformat.py:13: ShimWarning: The `IPython.nbformat` package has been deprecated since IPython 4.0. You should import from nbformat instead.
#   "You should import from nbformat instead.", ShimWarning)
# 79492
