# %%
# creating a variable
x=10

# %%
x
# Out:
# 10

# %%
print(x)
# Out:
# 10

# %%
type(x)
# Out:
# int

# %%
x='hi'
x
# Out:
# 'hi'

# %%
type(x)
# Out:
# str

# %%
a=True
a
# Out:
# True

# %%
type(a)
# Out:
# bool

# %%
a=4+5j
a
# Out:
# (4+5j)

# %%
type(a)
# Out:
# complex

# %%
a='hwisndiwdnss'
len(a)
# Out:
# 12
